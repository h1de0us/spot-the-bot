# %%
from esperanto_analyzer.analyzers.morphological import *
from esperanto_analyzer.speech import *

# %%
class Lemmatizer:
    def __init__(self):
        pass
    def lemmatize(self, word: str) -> str:
        # adjective
        adjective = AdjectiveMorphologicalAnalyzer(word)
        if adjective.analyze():
            #print("Word is an adjective!")
            new_word = list(word)
            if new_word[-1] == 'n':
                new_word.pop()
            if new_word[-1] == 'j':
                new_word.pop()
            return ''.join(new_word)
       
            
        
        # adverb
        adverb = AdverbMorphologicalAnalyzer(word)
        if adverb.analyze():
            #print("Word is an adverb!")
            new_word = list(word)
            if new_word[-1] == 'n':
                new_word.pop()
            return ''.join(new_word)
        
        # verb
        verb = VerbMorphologicalAnalyzer(word)
        if verb.analyze():
            #print("Word is a verb!")
            new_word = list(word)
            if new_word[-1] != 'i':
                new_word.pop() # глаголы заканчиваются на -as, -os, -is
                new_word.pop()
                new_word.append('i')
            return ''.join(new_word)
            
        
        # noun
        noun = NounMorphologicalAnalyzer(word)
        if noun.analyze():
            #print("Word is a noun!")
            new_word = list(word)
            if new_word[-1] == 'n':
                new_word.pop()
            if new_word[-1] == 'j':
                new_word.pop()
            return ''.join(new_word)
        
        
        # pronoun
        pronoun = PronounMorphologicalAnalyzer(word)
        if pronoun.analyze():
            #print("Word is a pronoun!")
            new_word = list(word)
            if new_word[-1] == 'n':
                new_word.pop()
            if new_word[-1] == 'j':
                new_word.pop()
            return ''.join(new_word)
          
            
        # article
        article = ArticleMorphologicalAnalyzer(word)
        if article.analyze():
            #print("Word is an article!")
            return word
        
        
        # conjunction
        conjunction = ConjunctionMorphologicalAnalyzer(word)
        if conjunction.analyze():
            #print("Word is a conjunction!")
            return word
        
        # preposition
        preposition = PrepositionMorphologicalAnalyzer(word)
        if preposition.analyze():
            #print("Word is a preposition")
            return word
    

        # number
        number = NumeralMorphologicalAnalyzer(word)
        if number.analyze():
            #print("Word is a number")
            return word
        
        # interjection
        interjection = InterjectionMorphologicalAnalyzer(word)
        if interjection.analyze():
            #print("Word is an interjection!")
            return word
        
        #print("Unknown word: may be a proper name or sth else")
        return ""

# %%
lemmatizer = Lemmatizer()

tests = ['belajn', 'hejme', 'iras', 'iri', 'vortaro', 'vortarojn', 'mi', 'vi', 'vin', 'siajn', 'la', 'kun', 'tri', 'deka', 'dekan', 'asdasdasd']
for test in tests:
    print(test, lemmatizer.lemmatize(test))
# Out:
# belajn bela
# hejme hejme
# iras iri
# iri iri
# vortaro vortaro
# vortarojn vortaro
# mi mi
# vi vi
# vin vi
# siajn sia
# la la
# kun kun
# tri tri
# deka deka
# dekan deka
# asdasdasd

# %%
def remove_punctuation(word: str) -> str:
    new_word = ''
    for letter in word:
        if letter.isalpha() or letter == '-':
            new_word += letter.lower()
    return new_word

# %%
def process_file(filename: str):
    with open(filename, "r") as file:
        out = open(filename + "_out", "w")
        for line in file.readlines():
            for word in line.split():
                processed_word = normalize_word(remove_punctuation(word))
                out.write(processed_word)
            out.write("\n")
        out.close()

# %%
# !ls -lh data
# Out:
# total 2048520
# -rw-r--r--@ 1 h1de0us  staff   126K Jul  7  2011 111-fabloj_RuLit_Net_99691.txt
# -rw-r--r--@ 1 h1de0us  staff    55K Oct  5  2012 Asch_La_sorcistino_el_Kastilio_RuLit_Net.txt
# -rw-r--r--@ 1 h1de0us  staff
# -rwxr-xr-x  1 h1de0us  staff   789B May 18  2008 gazetoj 2.txt
# -rwxr-xr-x@ 1 h1de0us  staff   1.1K Apr 24  2008 gazetoj.txt
# -rw-r--r--@ 1 h1de0us  staff   469K Jul  7  2011 gravitavio-carido_RuLit_Net_99693.txt
# -rwxr-xr-x  1 h1de0us  staff   212B May 15  2008 gulivero.txt
# -rwxr-xr-x  1 h1de0us  staff   147B May 23  2008 handzlik.txt
# -rw-r--r--@ 1 h1de0us  staff   944K Jul  7  2011 horo-de-bovo_RuLit_Net_99653.txt
# -rwxr-xr-x  1 h1de0us  staff   3.6K Jul 24  2008 informejo.txt
# -rwxr-xr-x  1 h1de0us  staff   360B May 15  2008 inicialojdc.txt
# -rwxr-xr-x  1 h1de0us  staff   344B May 15  2008 jomartnatasxa.txt
# -rwxr-xr-x  1 h1de0us  staff   389B May 16  2008 jomo.txt
# -rwxr-xr-x  1 h1de0us  staff   3.5K May 23  2008 kalendaro.txt
# -rwxr-xr-x  1 h1de0us  staff   219B May 15  2008 kapitano.txt
# -rwxr-xr-x  1 h1de0us  staff   2.8K Jul 24  2008 kd.txt
# -rw-r--r--@ 1 h1de0us  staff    19K Jan  5  2014 kojonov_luchjo.u.txt
# -rwxr-xr-x  1 h1de0us  staff   6.3K Jul 24  2008 komputilo.txt
# -rwxr-xr-x  1 h1de0us  staff   462B May 16  2008 kore.txt
# -rw-r--r--@ 1 h1de0us  staff   654K Jul  7  2011 la-nebulozo-de-andromedo_RuLit_Net_99675.txt
# -rw-r--r--@ 1 h1de0us  staff    52K Jan  6  2014 la_aventuro_de_la_dancantoj.u.txt
# -rw-r--r--@ 1 h1de0us  staff    65K Jan  6  2014 la_legendo_de_dorm-valeto.u.txt
# -rw-r--r--@ 1 h1de0us  staff   293K Jan  6  2014 la_smeralda_urbo_de_oz.u.txt
# -rw-r--r--@ 1 h1de0us  staff    45K Dec 22  2013 la_tajdo.u.txt
# -rwxr-xr-x  1 h1de0us  staff   381B May 15  2008 lafaraono.txt
# -rw-r--r--@ 1 h1de0us  staff   164K Jul  7  2011 lasu-min-paroli-plu_RuLit_Net_99639.txt
# -rwxr-xr-x  1 h1de0us  staff   435B May 16  2008 latalpoj.txt
# -rwxr-xr-x  1 h1de0us  staff   513B May 21  2008 ludo1.txt
# -rwxr-xr-x  1 h1de0us  staff   448B May  7  2008 ludo2.txt
# -rwxr-xr-x  1 h1de0us  staff   454B May  7  2008 ludo3.txt
# -rw-r--r--@ 1 h1de0us  staff   224K Jul  7  2011 magiisto-de-smeralda-urbo_RuLit_Net_99687.txt
# -rwxr-xr-x  1 h1de0us  staff   537B May 15  2008 malnovatestamento.txt
# -rwxr-xr-x  1 h1de0us  staff   290B May 15  2008 mojxajev.txt
# -rwxr-xr-x  1 h1de0us  staff   736B May 17  2008 monumento.txt
# -rw-r--r--@ 1 h1de0us  staff   315K Jan  7  2014 murdo_en_la_orienta_ekspreso.u.txt
# -rw-r--r--@ 1 h1de0us  staff   393K Jul  7  2011 naski-o-de-la-rustimuna-talrato_RuLit_Net_99663.txt
# -rwxr-xr-x  1 h1de0us  staff   222B May 29  2008 novatestamento.txt
# -rw-r--r--@ 1 h1de0us  staff   388K Jan  6  2014 o_de_la_rustimuna_talrato.u.txt
# -rwxr-xr-x  1 h1de0us  staff   424B May 15  2008 persone.txt
# -rwxr-xr-x  1 h1de0us  staff   212B May 15  2008 pinokjo.txt
# -rwxr-xr-x  1 h1de0us  staff   215B May 15  2008 proverbaro.txt
# -rwxr-xr-x  1 h1de0us  staff   306B May 15  2008 quovadis.txt
# -rw-r--r--@ 1 h1de0us  staff   6.3K Jan 11 16:02 rikki-tikki-tavi.u.txt
# -rw-r--r--@ 1 h1de0us  staff   440B Jan 11 15:52 rikki-tikki-tavi_RuLit_Net_99651.txt
# -rw-r--r--@ 1 h1de0us  staff   138K Jan 11 13:06 robinsono_kruso.u.txt
# -rwxr-xr-x  1 h1de0us  staff   331B May 15  2008 rogxerborgxes.txt
# -rwxr-xr-x  1 h1de0us  staff   431B May 16  2008 supernova.txt
# -rw-r--r--@ 1 h1de0us  staff   454K Jul  7  2011 tarzan-de-la-simioj_RuLit_Net_99573.txt
# -rw-r--r--@ 1 h1de0us  staff   451K Jan  7  2014 tarzan_de_la_simioj.u.txt
# -rwxr-xr-x  1 h1de0us  staff   5.8K May 23  2008 telefono.txt
# -rw-r--r--@ 1 h1de0us  staff    58K Jan  6  2014 tri_noveloj.u.txt

# %%
total_words = 0
missed_words = 0

def process_file(filename: str):
    global total_words, missed_words
    with open('data/' + filename, encoding='iso-8859-1') as file:
        out_filename = "processed_data/" + filename[:-4] + "_processed.txt"
        out = open(out_filename, "w")
        print
        for line in file.readlines():
            for word in line.split():
                processed_word = lemmatizer.lemmatize(remove_punctuation(word))
                total_words += 1
                #print(processed_word)
                out.write(processed_word)
                out.write(" ")
                if (processed_word == ""):
                    missed_words += 1
            out.write("\n")
        out.close()
    
print(total_words, missed_words)
# Out:
# 0 0

# %%
import os

directory = os.fsencode("data")
    
for file in os.listdir(directory):
    print(file)
    process_file(file.decode("utf-8"))
# Out:
# b'Piron_\xc4\x88u_ni_kunvenis_vane_RuLit_Net.txt'
# b'Bein_Vortaro-de-Esperanto-1910_RuLit_Me.txt'
# b'handzlik.txt'
# b'supernova.txt'
# b'Reyto_La_nigra_kapitano_RuLit_Net.txt'
# b'tarzan_de_la_simioj.u.txt'
# b'gulivero.txt'
# b'fabeloj_al_helenjo.u.txt'
# b'robinsono_kruso.u.txt'
# b'Zamenhof_Esenco-kaj-estonteco-de-la-ideo-de-Lingvo-Internacia_RuLit_Net.txt'
# b'Garrison_La-stratoj-de-Askelono_RuLit_Net.txt'
# b'la_aventuro_de_la_dancantoj.u.txt'
# b'Reyto_La_blonda_ciklono_RuLit_Net.txt'
# b'Konan_Doyl_La_ses_Napoleonoj_RuLit_Net.txt'
# b'monumento.txt'
# b'rogxerborgxes.txt'
# b'Baza-Radikaro-Oficiala_RuLit_Me.txt'
# b'kd.txt'
# b'Reyto_Fred_la_malpura_la_kapitano_RuLit_Net.txt'
# b'Reyto_Pariza_Fronto_RuLit_Net.txt'
# b'faktoj.txt'
# b'ludo2.txt'
# b'gazetoj.txt'
# b'ludo3.txt'
# b'Piron_\xc4\x88u_\xc5\x9di_mortu_tra-fike_RuLit_Net.txt'
# b'Pushkin_La-filino-de-la-kapitano_RuLit_Me.txt'
# b'jomartnatasxa.txt'
# b'Vojnic_Ojstro_RuLit_Me.txt'
# b'Marks_Manifesto-de-la-komunista-partio_RuLit_Me.txt'
# b'ce-la-koro-de-la-tero_RuLit_Net_99548.txt'
# b'tarzan-de-la-simioj_RuLit_Net_99573.txt'
# b'lasu-min-paroli-plu_RuLit_Net_99639.txt'
# b'Piron_\xc4\x88u_li_bremsis_sufice_RuLit_Net.txt'
# b'Rouling_Hari-Poter_1_Hari-Potter-kaj-la-Stono-de-la-Saguloj_RuLit_Me.txt'
# b'Dikkens_La-postlasitaj-paperoj-de-la-Klubo-Pikvika_RuLit_Me.txt'
# b'Gaydar_Timur-kaj-lia-tacmento_RuLit_Me.txt'
# b'ludo1.txt'
# b'Kokeny_Enciklopedio-de-Esperanto_RuLit_Me.txt'
# b'horo-de-bovo_RuLit_Net_99653.txt'
# b'Turgenev_Patroj-kaj-filoj_RuLit_Me.txt'
# b'Reyto_Kiuj_inter\xc5\x9dan\xc4\x9dis_vivon_RuLit_Net.txt'
# b'Turgenev_La_unua_amo_RuLit_Net.txt'
# b'o_de_la_rustimuna_talrato.u.txt'
# b'Avtor_neizvesten_La_Sankta_Biblio_RuLit_Net.txt'
# b'Ujlaky-Nagy_La-sporta-lingvo-en-Esperanto_RuLit_Me.txt'
# b'proverbaro.txt'
# b'Reyto_La_tri_korpogardistoj_en_Afriko_RuLit_Net.txt'
# b'kapitano.txt'
# b'Efremov_La_Granda_Arko_\xc4\x88e_la_rando_de_la_Ekumeno__RuLit_Net.txt'
# b'Avtor_neizzvesten_Fabloj_de_Cent_paraboloj_RuLit_Net.txt'
# b'inicialojdc.txt'
# b'ashundo_de_la_baskerviloj.u.txt'
# b'Ibsen_Puphejmo_RuLit_Net.txt'
# b'kore.txt'
# b'jomo.txt'
# b'Reyto_La_antauen\xc5\x9dovita_garnizono_RuLit_Net.txt'
# b'Old_Pasoj-al-plena-posedo_RuLit_Me.txt'
# b'Soderberg_La-kiso-kaj-dek-tri-aliaj-noveloj_RuLit_Net.txt'
# b'Tolstoy_LA_MORTO_DE_IVAN_ILJICx_RuLit_Net.txt'
# b'asorti.txt'
# b'Priva_Vivo_de_Zamenhof_RuLit_Net.txt'
# b'Zamenhof_La-dua-libro-de-l-lingvo-internacia_RuLit_Net.txt'
# b'desperado.txt'
# b'eklubo.txt'
# b'Ibsen_Eta_Eyolf_RuLit_Net.txt'
# b'la_smeralda_urbo_de_oz.u.txt'
# b'bretaro.txt'
# b'Pushkin_Fabelo-pri-ora-koko_RuLit_Me.txt'
# b'Boker_El_la_vivo_de_bervala_sentaugulo_RuLit_Net.txt'
# b'Zamengof_Proverbaro_Esperanta_RuLit_Net.txt'
# b'fatalaj-ovoj_RuLit_Net_99580.txt'
# b'Piron_\xc4\x88u_vi_kuiras_cine_RuLit_Net.txt'
# b'Dikkens_La-batalo-de-l-vivo_RuLit_Me.txt'
# b'informejo.txt'
# b'el_la_vivo_de_esperantistoj.u.txt'
# b'kalendaro.txt'
# b'rikki-tikki-tavi.u.txt'

# %%
# combine all processed files into one 
out_directory = os.fsencode("processed_data")

with open("result.txt", "w") as result:
    for filename in os.listdir(out_directory):
        if filename != b'.DS_Store' and filename.decode("utf-8") != "eo_wiki_corpus_processed.txt":
            file = open('processed_data/' + filename.decode("utf-8"), "r")
            for line in file.readlines():
                for word in line.split():
                    result.write(word)
                    result.write(" ")
            file.close()
            result.write('\n')

# %%
# !wc result.txt
# Out:
#      174 5659651 30821975 result.txt

# %%
# не записываю википедию в один файл с художественной литературой

# %%
# добавляю новые художественные тексты, газеты и веб-страницы

def process_file_2(filename: str, in_folder: str, out_folder: str):
    global total_words, missed_words
    with open(in_folder + filename, encoding='iso-8859-1') as file:
        out_filename = out_folder + filename[:-4] + "_processed.txt"
        out = open(out_filename, "w")
        print
        for line in file.readlines():
            for word in line.split():
                processed_word = lemmatizer.lemmatize(remove_punctuation(word))
                total_words += 1
                #print(processed_word)
                out.write(processed_word)
                out.write(" ")
                if (processed_word == ""):
                    missed_words += 1
            out.write("\n")
        out.close()
    
process_file_2("epo_literature_2011_300K-sentences.txt", "literature_300k/", "processed_literature_300k/")
print("Added literature")
process_file_2("epo_newscrawl_2017_300K-sentences.txt", "newscrawl_300k/", "processed_newscrawl_300k/")
print("Added newscrawl")
process_file_2("epo_web_2012_300K-sentences.txt", "web_300k/", "processed_web_300k/")
print("Added web pages")
# Out:
# Added literature
# Added newscrawl
# Added web pages

# %%
with open("result.txt", "a") as result:
    file = open('processed_literature_300k/epo_literature_2011_300K-sentences_processed.txt', "r")
    count = 0
    for line in file.readlines():
        for word in line.split():
            result.write(word)
            result.write(" ")
        if count % 300 == 0: # делаю пачки из 300 предложений
            result.write('\n')
        count += 1
            
    file.close()
    result.write('\n')

# %%
# !wc result.txt
# Out:
#     1175 9374293 50306260 result.txt

# %%
with open("result_newscrawl_and_web.txt", "w") as result:
    file = open('processed_newscrawl_300k/epo_newscrawl_2017_300K-sentences_processed.txt', "r")
    for line in file.readlines():
        for word in line.split():
            result.write(word)
            result.write(" ")
        if count % 300 == 0:
            result.write('\n')
        count += 1
    file.close()
    result.write('\n')
                
with open("result_newscrawl_and_web.txt", "a") as result:
    file = open('processed_web_300k/epo_web_2012_300K-sentences_processed.txt', "r")
    for line in file.readlines():
        for word in line.split():
            result.write(word)
            result.write(" ")
        if count % 300 == 0:
            result.write('\n')
        count += 1
    file.close()
    result.write('\n')

# %%
# !wc result_newscrawl_and_web.txt
# Out:
#     2002 8907981 51974248 result_newscrawl_and_web.txt

# %%
with open("result_wiki.txt", "w") as result:
    file = open('processed_data/eo_wiki_corpus_processed.txt', "r")
    for line in file.readlines():
        for word in line.split():
            result.write(word)
            result.write(" ")
        if count % 2000 == 0:
            result.write('\n')
    file.close()
    result.write('\n')

# %%
# !wc result_wiki.txt
# Out:
#  7612070 123484971 715483477 result_wiki.txt

# %%
token_pattern = "[A-Za-zĉĥĵŝŭĈĜĤĴŜŬ]+"

from sklearn.feature_extraction.text import TfidfVectorizer
def make_table_and_dict(corpus_path, min_df, max_df, token_pattern = None, use_idf = True):
    with open(corpus_path, 'r') as corpus_file:
        if token_pattern:
            vectorizer = TfidfVectorizer(analyzer='word', min_df=min_df, token_pattern=token_pattern, use_idf=use_idf)
        else:
            vectorizer = TfidfVectorizer(analyzer='word', min_df=min_df)
        data_vectorized = vectorizer.fit_transform(corpus_file)
    return data_vectorized, vectorizer.get_feature_names(), vectorizer.idf_

# %%
esp_data_vectorized, esp_dictionary, idfs = make_table_and_dict('result.txt', 0.01,  0.8 , token_pattern)
pairs = dict(zip(esp_dictionary, idfs))
with open('dictionary.txt', 'w') as output_file:
    for word in esp_dictionary:
        if (pairs[word] > 1.4):
            output_file.write(word)
            output_file.write('\n')

        else:
            print('here')
# Out:
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here
# here

# %%
pairs = list(zip(esp_dictionary, idfs))
sorted(pairs, key = lambda x: x[1])
# Out:
# [('en', 1.007682496172016),
#  ('la', 1.010256500167189),
#  ('de', 1.0119761910467155),
#  ('esti', 1.0119761910467155),
#  ('kaj', 1.0162884012648958),
#  ('pli', 1.0171530792262495),
#  ('da', 1.0206192872027355),
#  ('el', 1.0240975515790605),
#  ('ki', 1.0240975515790605),
#  ('por', 1.0240975515790605),
#  ('pri', 1.0240975515790605),
#  ('al', 1.0249690113292016),
#  ('kun', 1.0249690113292016),
#  ('kiu', 1.0258412311838874),
#  ('alia', 1.0284624646637617),
#  ('ili', 1.0284624646637617),
#  ('ti', 1.0284624646637617),
#  ('tio', 1.0284624646637617),
#  ('vi', 1.0284624646637617),
#  ('havi', 1.0293377382426168),
#  ('sia', 1.0293377382426168),
#  ('kiel', 1.0302137785964967),
#  ('povi', 1.0302137785964967),
#  ('fari', 1.031090587070031),
#  ('li', 1.031090587070031),
#  ('pro', 1.031090587070031),
#  ('per', 1.0319681650113899),
#  ('se', 1.0319681650113899),
#  ('sed', 1.0319681650113899),
#  ('tie', 1.0319681650113899),
#  ('tiu', 1.0319681650113899),
#  ('ui', 1.0319681650113899),
#  ('dum', 1.0328465137722962),
#  ('granda', 1.0328465137722962),
#  ('nu', 1.0328465137722962),
#  ('kiam', 1.0337256347080361),
#  ('oni', 1.0337256347080361),
#  ('sur', 1.0337256347080361),
#  ('diri', 1.0346055291774756),
#  ('ke', 1.0346055291774756),
#  ('mi', 1.0346055291774756),
#  ('ni', 1.0346055291774756),
#  ('kio', 1.035486198543069),
#  ('ol', 1.035486198543069),
#  ('vidi', 1.035486198543069),
#  ('homo', 1.0363676441708747),
#  ('jam', 1.0363676441708747),
#  ('lia', 1.0363676441708747),
#  ('voli', 1.0363676441708747),
#  ('devi', 1.038132869695444),
#  ('tre', 1.0390166523424518),
#  ('mia', 1.039901216752186),
#  ('io', 1.0407865643089103),
#  ('post', 1.0434473197589365),
#  ('scii', 1.0443358138200516),
#  ('iu', 1.046115173720129),
#  ('tute', 1.046115173720129),
#  ('veni', 1.046115173720129),
#  ('iri', 1.0478977053864122),
#  ('tuta', 1.0478977053864122),
#  ('nia', 1.0487901641694322),
#  ('bona', 1.052367985517316),
#  ('inter', 1.052367985517316),
#  ('via', 1.052367985517316),
#  ('tia', 1.053264444564353),
#  ('trovi', 1.053264444564353),
#  ('je', 1.0541617079713428),
#  ('tempo', 1.0541617079713428),
#  ('kie', 1.0559586536480445),
#  ('rigardi', 1.062273514506719),
#  ('vorto', 1.0631789016215316),
#  ('paroli', 1.0640851092050696),
#  ('bone', 1.0658999917358922),
#  ('okulo', 1.0658999917358922),
#  ('mano', 1.0668086696721104),
#  ('sinjoro', 1.0668086696721104),
#  ('vivo', 1.0668086696721104),
#  ('du', 1.0677181740549508),
#  ('afero', 1.069539668183342),
#  ('resti', 1.069539668183342),
#  ('doni', 1.0704516609506114),
#  ('kelka', 1.071364486207971),
#  ('pi', 1.0759411532353829),
#  ('multe', 1.0768590055256118),
#  ('tago', 1.0768590055256118),
#  ('eble', 1.0777777010426843),
#  ('kapo', 1.0786972413373628),
#  ('nenio', 1.0814609464589806),
#  ('viro', 1.0814609464589806),
#  ('neniam', 1.0851578083403068),
#  ('infano', 1.0870113769896297),
#  ('ilia', 1.0879394513021836),
#  ('sen', 1.0879394513021836),
#  ('tuj', 1.089798187896809),
#  ('tiam', 1.0935260580108235),
#  ('multa', 1.0944602010026205),
#  ('malgranda', 1.095395217433527),
#  ('jaro', 1.0963311089384322),
#  ('poste', 1.097267877156819),
#  ('bela', 1.1000834585569825),
#  ('komenci', 1.1000834585569825),
#  ('domo', 1.1029069898445891),
#  ('respondi', 1.1029069898445891),
#  ('pensi', 1.1057385160403275),
#  ('loko', 1.1076306641923654),
#  ('neni', 1.1076306641923654),
#  ('unua', 1.1085780825484053),
#  ('sub', 1.1133286853070032),
#  ('stari', 1.114281520062275),
#  ('virino', 1.1152352635775848),
#  ('mondo', 1.1161899175880354),
#  ('nova', 1.1161899175880354),
#  ('okazi', 1.1190593600159882),
#  ('montri', 1.12097690614526),
#  ('tra', 1.125786920229045),
#  ('dio', 1.128684073390198),
#  ('patro', 1.128684073390198),
#  ('senti', 1.128684073390198),
#  ('sola', 1.1296516593389336),
#  ('vojo', 1.1306201824170643),
#  ('kompreni', 1.135476918530014),
#  ('demandi', 1.1393793625069457),
#  ('preni', 1.1393793625069457),
#  ('ricevi', 1.1393793625069457),
#  ('momento', 1.1403573576949224),
#  ('kia', 1.1423162221802554),
#  ('denove', 1.1432970952358474),
#  ('sama', 1.1531591081049632),
#  ('koro', 1.1571313079653962),
#  ('tro', 1.1581268282068977),
#  ('nomo', 1.1591233404966368),
#  ('propra', 1.1621188494764352),
#  ('same', 1.1621188494764352),
#  ('juna', 1.1641208521471083),
#  ('lando', 1.165123358496734),
#  ('kredi', 1.1681369218019981),
#  ('sidi', 1.1691434644133996),
#  ('longa', 1.1721691853299367),
#  ('apud', 1.1731797968358602),
#  ('pordo', 1.1731797968358602),
#  ('tero', 1.1762177738559367),
#  ('rapide', 1.1782482314063187),
#  ('amiko', 1.1792650083114056),
#  ('longe', 1.1833424859280617),
#  ('akvo', 1.1864115420454797),
#  ('meti', 1.1864115420454797),
#  ('vere', 1.1864115420454797),
#  ('patrino', 1.193609516567806),
#  ('super', 1.193609516567806),
#  ('knabino', 1.1946420411819951),
#  ('urbo', 1.195675633005278),
#  ('atendi', 1.1998207166604467),
#  ('lasi', 1.2008596777928657),
#  ('tri', 1.208162787977842),
#  ('kvankam', 1.217631559406694),
#  ('ekzisti', 1.2208078458251146),
#  ('rakonti', 1.2229309888731925),
#  ('kies', 1.22719084622015),
#  ('lasta', 1.2282586519809802),
#  ('bezoni', 1.2293275991698853),
#  ('peti', 1.2303976902297296),
#  ('vivi', 1.233614851181505),
#  ('reveni', 1.2346895423112705),
#  ('atingi', 1.2357653896447336),
#  ('koni', 1.2368423956723715),
#  ('ofte', 1.2368423956723715),
#  ('fali', 1.2389998938123927),
#  ('laboro', 1.2389998938123927),
#  ('nokto', 1.2389998938123927),
#  ('plena', 1.24224489395572),
#  ('porti', 1.2433289049019784),
#  ('certe', 1.2444140922032654),
#  ('alta', 1.2476767378380818),
#  ('eniri', 1.2487666562021074),
#  ('nek', 1.2564295289476766),
#  ('knabo', 1.2597316783434356),
#  ('esi', 1.261939184758646),
#  ('maljuna', 1.261939184758646),
#  ('deziri', 1.2641515750415868),
#  ('penso', 1.2641515750415868),
#  ('horo', 1.2663688708502343),
#  ('edzino', 1.268591093986952),
#  ('blanka', 1.2708182663997762),
#  ('helpi', 1.2719337154836419),
#  ('persono', 1.274168353285058),
#  ('subite', 1.2786526657323867),
#  ('ami', 1.2842864834506427),
#  ('rimarki', 1.2842864834506427),
#  ('jen', 1.2876820724517808),
#  ('krii', 1.2910892307733952),
#  ('korpo', 1.294508037522181),
#  ('piedo', 1.294508037522181),
#  ('morti', 1.2967937528030369),
#  ('foriri', 1.29793857261897),
#  ('opinii', 1.2990847045495926),
#  ('sinjorino', 1.3002321516060693),
#  ('vera', 1.3002321516060693),
#  ('uzi', 1.30253100319318),
#  ('amo', 1.3106188577948792),
#  ('parto', 1.3106188577948792),
#  ('aperi', 1.3117796240308415),
#  ('timi', 1.3164362098607925),
#  ('animo', 1.3176037523168302),
#  ('kapti', 1.3176037523168302),
#  ('forta', 1.318772659521812),
#  ('fojo', 1.3199429346700025),
#  ('morto', 1.32463777897421),
#  ('popolo', 1.32463777897421),
#  ('tial', 1.32463777897421),
#  ('malnova', 1.3281734338065179),
#  ('sekvi', 1.3293547688523488),
#  ('nigra', 1.3317216338626152),
#  ('tablo', 1.336472236621213),
#  ('lingvo', 1.3376634219913661),
#  ('nomi', 1.3376634219913661),
#  ('arbo', 1.3412455153738705),
#  ('demando', 1.3424424036077167),
#  ('malbona', 1.3448404862917296),
#  ('turni', 1.3460416876373638),
#  ('forto', 1.347244333603124),
#  ('grava', 1.3544907421238914),
#  ('levi', 1.359351019006144),
#  ('arbaro', 1.3605697882002734),
#  ('brako', 1.3605697882002734),
#  ('fenestro', 1.3605697882002734),
#  ('libro', 1.3605697882002734),
#  ('kara', 1.3642350335985693),
#  ('certa', 1.3679137624560318),
#  ('stranga', 1.3679137624560318),
#  ('forlasi', 1.3691430189107616),
#  ('teni', 1.3740752114000805),
#  ('malpli', 1.3753120699374768),
#  ('besto', 1.3765504601886234),
#  ('facile', 1.3790318510400088),
#  ('kial', 1.380274859279606),
#  ('aspekti', 1.3827655205920577),
#  ('renkonti', 1.3877655310087635),
#  ('kune', 1.3902749426141892),
#  ('ideo', 1.3927906672114365),
#  ('sukcesi', 1.3940509068237243),
#  ('akcepti', 1.3953127366441465),
#  ('for', 1.3953127366441465),
#  ('perdi', 1.3953127366441465),
#  ('muro', 1.399107807612698),
#  ('terura', 1.4003760386006932),
#  ('dek', 1.4029173360293656),
#  ('konduki', 1.4029173360293656),
#  ('krom', 1.4029173360293656),
#  ('maniero', 1.4029173360293656),
#  ('mono', 1.408019387913261),
#  ('sento', 1.4092989786188863),
#  ('eliri', 1.411863082587824),
#  ('provi', 1.4157216082753534),
#  ('rigardo', 1.4195950798711503),
#  ('eta', 1.4234836136108426),
#  ('fajro', 1.4234836136108426),
#  ('skribi', 1.4339275727719258),
#  ('homa', 1.4365556951781955),
#  ('dua', 1.4418327522790393),
#  ('lumo', 1.4471378045087324),
#  ('malaperi', 1.4471378045087324),
#  ('dormi', 1.452471150484095),
#  ('pastro', 1.4538089433257548),
#  ('letero', 1.4605248852911918),
#  ('kuri', 1.4645762075103703),
#  ('maro', 1.4645762075103703),
#  ('simila', 1.4659303038580997),
#  ('labori', 1.4672862362692356),
#  ('forte', 1.468644009729696),
#  ('lito', 1.468644009729696),
#  ('ordoni', 1.4700036292457357),
#  ('legi', 1.4727284265719207),
#  ('kvar', 1.4754606687087937),
#  ('forgesi', 1.4837024736038975),
#  ('sendi', 1.4850827360728558),
#  ('hundo', 1.4864649062998074),
#  ('ludi', 1.4892349911736231),
#  ('alveni', 1.4920127707375255),
#  ('suno', 1.4947982878589519),
#  ('formo', 1.4975915857645645),
#  ('efektive', 1.5003927080442763),
#  ('prezenti', 1.5017962170465964),
#  ('ridi', 1.5017962170465964),
#  ('vesto', 1.5017962170465964),
#  ('decidi', 1.504609158423211),
#  ('klarigi', 1.504609158423211),
#  ('trans', 1.5060186019264448),
#  ('viziti', 1.5116763256463037),
#  ('okazo', 1.5130957723005298),
#  ('veturi', 1.5130957723005298),
#  ('aero', 1.5145172366479074),
#  ('regi', 1.5145172366479074),
#  ('timo', 1.5173662414239821),
#  ('kvin', 1.5216550256961998),
#  ('klare', 1.5230887176980483),
#  ('intenci', 1.5245244681241528),
#  ('malfermi', 1.5259622828937802),
#  ('diversa', 1.5317343046909024),
#  ('samtempe', 1.5346328574449137),
#  ('monto', 1.5360852905252287),
#  ('edzo', 1.543379268887782),
#  ('halti', 1.543379268887782),
#  ('junulo', 1.543379268887782),
#  ('celo', 1.54484447061511),
#  ('vero', 1.54484447061511),
#  ('vespero', 1.5492530008998762),
#  ('familio', 1.5522028555462972),
#  ('voki', 1.5536810524156082),
#  ('ago', 1.5566440175462652),
#  ('objekto', 1.5581287988138444),
#  ('respondo', 1.5581287988138444),
#  ('alporti', 1.5625964160735606),
#  ('ora', 1.5655859549219264),
#  ('unue', 1.568584457918183),
#  ('malamiko', 1.5730991382727098),
#  ('nepre', 1.574608572521564),
#  ('rekte', 1.574608572521564),
#  ('permesi', 1.576120288606886),
#  ('verda', 1.577634293438101),
#  ('aparteni', 1.579150593956065),
#  ('memori', 1.580669197133255),
#  ('opinio', 1.5867667770013736),
#  ('pasi', 1.591364486250003),
#  ('minuto', 1.5959834321062976),
#  ('kampo', 1.5975278339576717),
#  ('posedi', 1.5975278339576717),
#  ('profunda', 1.6006238116627998),
#  ('simpla', 1.6006238116627998),
#  ('rajti', 1.6037294042209527),
#  ('sankta', 1.6068446715379021),
#  ('vento', 1.6084059521048546),
#  ('rivero', 1.6099696740810374),
#  ('ekstere', 1.6115358451137825),
#  ('orelo', 1.6115358451137825),
#  ('postuli', 1.613104472886409),
#  ('plene', 1.6178251740213463),
#  ('neniu', 1.619403706314396),
#  ('plenumi', 1.622568265917359),
#  ('mortigi', 1.6241543090729937),
#  ('malrapide', 1.6257428717581317),
#  ('preta', 1.6257428717581317),
#  ('brusto', 1.6305237573584737),
#  ('ree', 1.6305237573584737),
#  ('gaja', 1.6337237600891445),
#  ('hejmo', 1.6337237600891445),
#  ('libera', 1.6369340357193929),
#  ('princo', 1.641768855773976),
#  ('deziro', 1.6531418459462461),
#  ('historio', 1.6547771692869768),
#  ('nenia', 1.6547771692869768),
#  ('parolo', 1.6564151712912154),
#  ('kapabli', 1.6580558607486753),
#  ('supren', 1.6580558607486753),
#  ('aldoni', 1.6596992464924052),
#  ('haro', 1.6596992464924052),
#  ('ombro', 1.6596992464924052),
#  ('agi', 1.6613453373990739),
#  ('larmo', 1.6629941423892578),
#  ('iomete', 1.6662999305237571),
#  ('savi', 1.6662999305237571),
#  ('doroteo', 1.667956931731387),
#  ('foje', 1.6696166831497512),
#  ('kanti', 1.6696166831497512),
#  ('proksime', 1.6696166831497512),
#  ('trinki', 1.6696166831497512),
#  ('plori', 1.6712791939233647),
#  ('proksima', 1.6779570150659702),
#  ('birdo', 1.6813127229129425),
#  ('amaso', 1.6846797294608469),
#  ('batalo', 1.6846797294608469),
#  ('naturo', 1.6846797294608469),
#  ('peza', 1.6846797294608469),
#  ('temi', 1.6846797294608469),
#  ('ekvidi', 1.6863674935745665),
#  ('lerni', 1.6880581110524742),
#  ('malfacile', 1.689751591558807),
#  ('sango', 1.689751591558807),
#  ('bildo', 1.6931471805599454),
#  ('ordono', 1.6948493086304757),
#  ('signifi', 1.6948493086304757),
#  ('doloro', 1.6965543388815596),
#  ('precipe', 1.699973145630345),
#  ('dorso', 1.70168694210808),
#  ('manki', 1.70168694210808),
#  ('peni', 1.70168694210808),
#  ('kreski', 1.705123371606661),
#  ('bordo', 1.708571650885577),
#  ('frue', 1.710300259786195),
#  ('milii', 1.710300259786195),
#  ('akiri', 1.7120318619504729),
#  ('palaco', 1.713766467762681),
#  ('alie', 1.7172447321390059),
#  ('farita', 1.7172447321390059),
#  ('kuracisto', 1.7207351370787742),
#  ('konsenti', 1.7242377676299765),
#  ('mastro', 1.7259936943322414),
#  ('grupo', 1.7312800502553893),
#  ('atenti', 1.7348198769605134),
#  ('dika', 1.7365945003188819),
#  ('fai', 1.7365945003188819),
#  ('helpo', 1.738372278564881),
#  ('okupi', 1.738372278564881),
#  ('tria', 1.738372278564881),
#  ('kruro', 1.7419373447293773),
#  ('peco', 1.743724655303473),
#  ('angulo', 1.7455151660772612),
#  ('kompreneble', 1.7455151660772612),
#  ('suferi', 1.7455151660772612),
#  ('malsupren', 1.7473088885312882),
#  ('krei', 1.74910583420799),
#  ('rekoni', 1.74910583420799),
#  ('servisto', 1.74910583420799),
#  ('volo', 1.74910583420799),
#  ('lipo', 1.7509060147121378),
#  ('situacio', 1.7509060147121378),
#  ('mateno', 1.7527094417112883),
#  ('ii', 1.7545161269362373),
#  ('frai', 1.7599558502320556),
#  ('malproksime', 1.7599558502320556),
#  ('ekscii', 1.7617756869490417),
#  ('malmulte', 1.765425326036591),
#  ('simili', 1.765425326036591),
#  ('grandega', 1.767255152713667),
#  ('mallonga', 1.7690883337953283),
#  ('rigardante', 1.7690883337953283),
#  ('ekkrii', 1.7709248816026295),
#  ('kanto', 1.7709248816026295),
#  ('potenco', 1.7709248816026295),
#  ('pura', 1.7709248816026295),
#  ('rifuzi', 1.7727648085246366),
#  ('signo', 1.7727648085246366),
#  ('planko', 1.774608127018926),
#  ('rimedo', 1.774608127018926),
#  ('espero', 1.7764548496120907),
#  ('igi', 1.7764548496120907),
#  ('promesi', 1.7764548496120907),
#  ('blua', 1.7783049889002522),
#  ('mil', 1.7783049889002522),
#  ('supozi', 1.7783049889002522),
#  ('trankvila', 1.7783049889002522),
#  ('klara', 1.780158557549575),
#  ('profunde', 1.7820155682967878),
#  ('proponi', 1.7838760339497075),
#  ('sono', 1.7838760339497075),
#  ('spirii', 1.7838760339497075),
#  ('fremda', 1.7857399673877703),
#  ('dudek', 1.7876073815625657),
#  ('trankvile', 1.7876073815625657),
#  ('elekti', 1.793230639116928),
#  ('esprimo', 1.793230639116928),
#  ('forkuri', 1.793230639116928),
#  ('vico', 1.793230639116928),
#  ('bati', 1.7951121072166334),
#  ('rapidi', 1.7951121072166334),
#  ('rideti', 1.7969971219124048),
#  ('soldati', 1.7969971219124048),
#  ('kovri', 1.7988856966002729),
#  ('pagi', 1.7988856966002729),
#  ('plezuro', 1.8007778447523106),
#  ('simple', 1.8007778447523106),
#  ('belega', 1.8026735799172098),
#  ('frazo', 1.8045729157208625),
#  ('frunto', 1.8045729157208625),
#  ('signifo', 1.8045729157208625),
#  ('vii', 1.8064758658669486),
#  ('brili', 1.80838244413753),
#  ('soni', 1.80838244413753),
#  ('speco', 1.80838244413753),
#  ('konata', 1.8102926643936494),
#  ('premi', 1.8102926643936494),
#  ('ekster', 1.8122065405759336),
#  ('servi', 1.8122065405759336),
#  ('sorto', 1.8122065405759336),
#  ('volonte', 1.8122065405759336),
#  ('potenca', 1.8141240867052053),
#  ('dii', 1.8160453168830992),
#  ('eviti', 1.8160453168830992),
#  ('armeo', 1.8179702452926838),
#  ('malvarma', 1.8179702452926838),
#  ('semajno', 1.819898886199089),
#  ('gasto', 1.8218312539501431),
#  ('plenigi', 1.8218312539501431),
#  ('esperi', 1.8276508630034072),
#  ('etendi', 1.8276508630034072),
#  ('frapi', 1.8276508630034072),
#  ('mallumo', 1.8276508630034072),
#  ('varma', 1.8276508630034072),
#  ('esprimi', 1.8295982832878026),
#  ('hejme', 1.8315495034190645),
#  ('salti', 1.8315495034190645),
#  ('tasko', 1.8315495034190645),
#  ('vestita', 1.8315495034190645),
#  ('pala', 1.8374261119080497),
#  ('ses', 1.8374261119080497),
#  ('kutime', 1.8393926808800902),
#  ('memoro', 1.8393926808800902),
#  ('rilati', 1.8393926808800902),
#  ('strai', 1.841363124867389),
#  ('kolero', 1.8433374591711067),
#  ('kolo', 1.8433374591711067),
#  ('poi', 1.8453156991832125),
#  ('tiri', 1.8512740087668431),
#  ('kapitano', 1.8532680273737072),
#  ('ordinara', 1.8532680273737072),
#  ('reiri', 1.8532680273737072),
#  ('ebli', 1.8552660300363804),
#  ('kastelo', 1.8552660300363804),
#  ('silento', 1.8552660300363804),
#  ('bele', 1.8572680327070537),
#  ('meze', 1.8572680327070537),
#  ('stai', 1.8572680327070537),
#  ('direkto', 1.8612841023619435),
#  ('rideto', 1.8612841023619435),
#  ('maljunulo', 1.8632982017336448),
#  ('pano', 1.8632982017336448),
#  ('akompani', 1.865316365889882),
#  ('kelkfoje', 1.8673386112706496),
#  ('devigi', 1.869364954415882),
#  ('venki', 1.869364954415882),
#  ('silenti', 1.8734300006640516),
#  ('duono', 1.8754687373538999),
#  ('instrui', 1.8754687373538999),
#  ('fratino', 1.8775116389837),
#  ('vino', 1.8775116389837),
#  ('devo', 1.8795587226054251),
#  ('pasigi', 1.8795587226054251),
#  ('imagi', 1.8816100053759823),
#  ('plura', 1.885725237521089),
#  ('regiono', 1.8898574748059995),
#  ('vespere', 1.8898574748059995),
#  ('kontenta', 1.891930014407972),
#  ('malbone', 1.891930014407972),
#  ('necesa', 1.8940068583528111),
#  ('preferi', 1.8940068583528111),
#  ('problemo', 1.8940068583528111),
#  ('observi', 1.8960880245566356),
#  ('veki', 1.8960880245566356),
#  ('nazo', 1.8981735310476568),
#  ('aspekto', 1.9002633959671162),
#  ('fakto', 1.9002633959671162),
#  ('ripeti', 1.9002633959671162),
#  ('gardi', 1.9023576375702311),
#  ('natura', 1.9023576375702311),
#  ('mieno', 1.9044562742271522),
#  ('rajto', 1.9044562742271522),
#  ('fermi', 1.906559324423931),
#  ('fremdulo', 1.906559324423931),
#  ('kutimi', 1.906559324423931),
#  ('karaktero', 1.9086668067634958),
#  ('klopodi', 1.9086668067634958),
#  ('stelo', 1.9086668067634958),
#  ('folio', 1.9107787399666394),
#  ('honoro', 1.9107787399666394),
#  ('klini', 1.9107787399666394),
#  ('silente', 1.9107787399666394),
#  ('ataki', 1.9128951428730168),
#  ('korto', 1.9128951428730168),
#  ('agrabla', 1.9150160344421545),
#  ('batali', 1.9150160344421545),
#  ('cent', 1.9150160344421545),
#  ('deklari', 1.9150160344421545),
#  ('zorgi', 1.9150160344421545),
#  ('konfesi', 1.9171414337544679),
#  ('oro', 1.9171414337544679),
#  ('partopreni', 1.9171414337544679),
#  ('rilate', 1.9171414337544679),
#  ('liberigi', 1.919271360012293),
#  ('pripensi', 1.919271360012293),
#  ('papero', 1.9214058325409256),
#  ('akra', 1.9235448707896747),
#  ('necesi', 1.9235448707896747),
#  ('delikata', 1.9256884943329262),
#  ('konsideri', 1.9256884943329262),
#  ('aro', 1.9278367228712159),
#  ('ozma', 1.9278367228712159),
#  ('precize', 1.9278367228712159),
#  ('rando', 1.9278367228712159),
#  ('koloro', 1.929989576232317),
#  ('rompi', 1.929989576232317),
#  ('malfacila', 1.9321470743723381),
#  ('nokte', 1.9321470743723381),
#  ('soldai', 1.9321470743723381),
#  ('intereso', 1.9343092373768334),
#  ('malbono', 1.9343092373768334),
#  ('supre', 1.9343092373768334),
#  ('vasta', 1.9343092373768334),
#  ('prepari', 1.9364760854619236),
#  ('kompatinda', 1.9386476389754315),
#  ('spiriti', 1.9386476389754315),
#  ('nuna', 1.940823918398027),
#  ('sendube', 1.940823918398027),
#  ('bruo', 1.9430049443443873),
#  ('certigi', 1.9430049443443873),
#  ('konservi', 1.9430049443443873),
#  ('frati', 1.9451907375643676),
#  ('malforta', 1.9451907375643676),
#  ('alte', 1.9473813189441862),
#  ('doktoro', 1.9473813189441862),
#  ('griza', 1.9473813189441862),
#  ('interne', 1.9473813189441862),
#  ('verko', 1.9473813189441862),
#  ('lernejo', 1.949576709507622),
#  ('tombo', 1.949576709507622),
#  ('tono', 1.949576709507622),
#  ('cetera', 1.956191948626341),
#  ('ordo', 1.956191948626341),
#  ('miri', 1.9628512407163181),
#  ('plano', 1.9628512407163181),
#  ('lago', 1.965080896043587),
#  ('malsano', 1.965080896043587),
#  ('direkti', 1.9673155338450035),
#  ('tremi', 1.9673155338450035),
#  ('obei', 1.9695551764385082),
#  ('kutimo', 1.971799846292332),
#  ('menso', 1.971799846292332),
#  ('malproksima', 1.9740495660263475),
#  ('dirante', 1.9763043584134365),
#  ('aparta', 1.978564246380874),
#  ('atento', 1.978564246380874),
#  ('princino', 1.978564246380874),
#  ('pruvi', 1.978564246380874),
#  ('registaro', 1.9808292530117262),
#  ('insulo', 1.9830994015462653),
#  ('forigi', 1.9853747153834007),
#  ('danki', 1.987655218082126),
#  ('ekzemple', 1.987655218082126),
#  ('senco', 1.987655218082126),
#  ('kisi', 1.9899409333629823),
#  ('pendi', 1.992231885109538),
#  ('saluti', 1.992231885109538),
#  ('zorge', 1.992231885109538),
#  ('bieno', 1.994528097369888),
#  ('ebla', 1.994528097369888),
#  ('komenco', 1.994528097369888),
#  ('serioza', 1.994528097369888),
#  ('gepatro', 1.9968295943581673),
#  ('kamarado', 1.9968295943581673),
#  ('kovrita', 1.9968295943581673),
#  ('paco', 1.9968295943581673),
#  ('malhelpi', 1.9991364004560823),
#  ('rapida', 2.003766038354825),
#  ('sekreto', 2.003766038354825),
#  ('terure', 2.003766038354825),
#  ('veturilo', 2.003766038354825),
#  ('rakoni', 2.0084172095305552),
#  ('aserti', 2.0107509328767756),
#  ('bono', 2.0107509328767756),
#  ('kutima', 2.0107509328767756),
#  ('leono', 2.0107509328767756),
#  ('scio', 2.0107509328767756),
#  ('strati', 2.0107509328767756),
#  ('afabla', 2.0130901152299474),
#  ('movi', 2.0130901152299474),
#  ('vei', 2.0130901152299474),
#  ('laca', 2.015434782189202),
#  ('kato', 2.0177849595341555),
#  ('roko', 2.0177849595341555),
#  ('birdotimigilo', 2.0201406732266145),
#  ('starigi', 2.0201406732266145),
#  ('cirkonstanco', 2.022501949412294),
#  ('vivanta', 2.02486881442256),
#  ('cerbo', 2.027241294776191),
#  ('malhela', 2.027241294776191),
#  ('brila', 2.032003208536435),
#  ('teruro', 2.032003208536435),
#  ('cedi', 2.034392695933816),
#  ('malfermita', 2.034392695933816),
#  ('sekve', 2.034392695933816),
#  ('vango', 2.034392695933816),
#  ('herbo', 2.0367879066597707),
#  ('inviti', 2.0367879066597707),
#  ('konstati', 2.0367879066597707),
#  ('venigi', 2.0367879066597707),
#  ('benko', 2.039188868197309),
#  ('cetere', 2.039188868197309),
#  ('esperani', 2.039188868197309),
#  ('junulino', 2.039188868197309),
#  ('interrompi', 2.041595608227874),
#  ('sklavo', 2.041595608227874),
#  ('decido', 2.0464265354975395),
#  ('maldika', 2.0464265354975395),
#  ('videbla', 2.0464265354975395),
#  ('danci', 2.0488507791090456),
#  ('ludo', 2.0488507791090456),
#  ('fakte', 2.0512809139623376),
#  ('severa', 2.0512809139623376),
#  ('defendi', 2.053716968760219),
#  ('johano', 2.053716968760219),
#  ('konsisti', 2.053716968760219),
#  ('koridoro', 2.053716968760219),
#  ('malfrue', 2.053716968760219),
#  ('pasinta', 2.053716968760219),
#  ('malalta', 2.0561589724157705),
#  ('kelke', 2.0586069540544107),
#  ('krio', 2.0586069540544107),
#  ('pordego', 2.0586069540544107),
#  ('silenta', 2.0586069540544107),
#  ('celi', 2.061060943015977),
#  ('ege', 2.061060943015977),
#  ('interna', 2.061060943015977),
#  ('multo', 2.061060943015977),
#  ('speciala', 2.061060943015977),
#  ('genuo', 2.0635209688568397),
#  ('malmulta', 2.0635209688568397),
#  ('nura', 2.0635209688568397),
#  ('salono', 2.0635209688568397),
#  ('impreso', 2.0659870613520335),
#  ('nacio', 2.0659870613520335),
#  ('punkto', 2.068459250497422),
#  ('ripozi', 2.068459250497422),
#  ('estro', 2.070937566511889),
#  ('generalo', 2.070937566511889),
#  ('lai', 2.070937566511889),
#  ('matene', 2.070937566511889),
#  ('donaco', 2.073422039839551),
#  ('eltiri', 2.073422039839551),
#  ('fermita', 2.073422039839551),
#  ('nome', 2.073422039839551),
#  ('temo', 2.073422039839551),
#  ('regno', 2.075912701152003),
#  ('rolo', 2.075912701152003),
#  ('sciigi', 2.075912701152003),
#  ('anonci', 2.0784095813505905),
#  ('konstrui', 2.0784095813505905),
#  ('monati', 2.0784095813505905),
#  ('serioze', 2.0784095813505905),
#  ('internacia', 2.0834221231741346),
#  ('prefere', 2.0834221231741346),
#  ('toleri', 2.0834221231741346),
#  ('nomata', 2.0859378477713815),
#  ('nubo', 2.0859378477713815),
#  ('malplena', 2.0884599172040916),
#  ('mortinta', 2.09098836355745),
#  ('gaje', 2.0935232191606383),
#  ('mizera', 2.0935232191606383),
#  ('staranta', 2.0935232191606383),
#  ('duone', 2.096064516589311),
#  ('glavo', 2.096064516589311),
#  ('valo', 2.096064516589311),
#  ('dia', 2.09861228866811),
#  ('eraro', 2.09861228866811),
#  ('malsana', 2.09861228866811),
#  ('nekonata', 2.09861228866811),
#  ('eternulo', 2.1011665684732064),
#  ('proksimume', 2.1011665684732064),
#  ('kuirejo', 2.10372738933488),
#  ('sufero', 2.10372738933488),
#  ('vendi', 2.106294784840126),
#  ('doi', 2.1088687888352986),
#  ('limo', 2.1088687888352986),
#  ('membro', 2.1088687888352986),
#  ('supro', 2.1088687888352986),
#  ('truo', 2.1088687888352986),
#  ('armilo', 2.1114494354287903),
#  ('franca', 2.1114494354287903),
#  ('monteto', 2.1114494354287903),
#  ('tegmento', 2.1114494354287903),
#  ('komuna', 2.114036758993741),
#  ('krimo', 2.114036758993741),
#  ('meriti', 2.114036758993741),
#  ('nobla', 2.114036758993741),
#  ('kapablo', 2.116630794170788),
#  ('malgaja', 2.116630794170788),
#  ('manko', 2.116630794170788),
#  ('nacia', 2.116630794170788),
#  ('strange', 2.116630794170788),
#  ('dormo', 2.1192315758708453),
#  ('fama', 2.1192315758708453),
#  ('nombro', 2.1192315758708453),
#  ('spaco', 2.1192315758708453),
#  ('egale', 2.121839139277926),
#  ('forpreni', 2.121839139277926),
#  ('muziko', 2.121839139277926),
#  ('nuda', 2.124453519851997),
#  ('mizero', 2.127074753331871),
#  ('konsilo', 2.1297028757381407),
#  ('angla', 2.132337923376146),
#  ('mezo', 2.132337923376146),
#  ('militi', 2.132337923376146),
#  ('viva', 2.132337923376146),
#  ('arto', 2.1349799328389842),
#  ('dento', 2.1349799328389842),
#  ('kvieta', 2.1349799328389842),
#  ('templo', 2.1349799328389842),
#  ('distanco', 2.1376289410105613),
#  ('sperti', 2.1376289410105613),
#  ('ulo', 2.1376289410105613),
#  ('gravi', 2.1402849850686776),
#  ('interesa', 2.1402849850686776),
#  ('lerta', 2.1402849850686776),
#  ('uzata', 2.1429481024881616),
#  ('vidante', 2.1429481024881616),
#  ('diveni', 2.1456183310440404),
#  ('mirinda', 2.1456183310440404),
#  ('murmuri', 2.1456183310440404),
#  ('vane', 2.1456183310440404),
#  ('honesta', 2.1482957088147567),
#  ('kredo', 2.1482957088147567),
#  ('onklo', 2.1482957088147567),
#  ('propono', 2.1482957088147567),
#  ('bezono', 2.1509802741854256),
#  ('intenco', 2.1509802741854256),
#  ('fonto', 2.1536720658511372),
#  ('konstante', 2.1536720658511372),
#  ('malluma', 2.1536720658511372),
#  ('mola', 2.1536720658511372),
#  ('petro', 2.1536720658511372),
#  ('ekiri', 2.1563711228203024),
#  ('sep', 2.1563711228203024),
#  ('transdoni', 2.1563711228203024),
#  ('kolekti', 2.159077484418045),
#  ('servistino', 2.1617911902896414),
#  ('densa', 2.1645122804040016),
#  ('erari', 2.1645122804040016),
#  ('minaci', 2.1645122804040016),
#  ('rido', 2.1645122804040016),
#  ('seka', 2.1645122804040016),
#  ('malamo', 2.1699767748760808),
#  ('paro', 2.1699767748760808),
#  ('glaso', 2.1727202608218317),
#  ('ligna', 2.1727202608218317),
#  ('rememori', 2.1727202608218317),
#  ('transiri', 2.1727202608218317),
#  ('amata', 2.1754712941937213),
#  ('detrui', 2.1754712941937213),
#  ('elteni', 2.1754712941937213),
#  ('evidente', 2.1754712941937213),
#  ('klarigo', 2.1754712941937213),
#  ('promeni', 2.1754712941937213),
#  ('diablo', 2.178229916632801),
#  ('eterna', 2.178229916632801),
#  ('movo', 2.178229916632801),
#  ('principo', 2.178229916632801),
#  ('skui', 2.178229916632801),
#  ('utila', 2.178229916632801),
#  ('preter', 2.1809961701256912),
#  ('stana', 2.1809961701256912),
#  ('beleco', 2.1837700970084164),
#  ('gajni', 2.1837700970084164),
#  ('havigi', 2.1837700970084164),
#  ('atente', 2.189341142057872),
#  ('esplori', 2.189341142057872),
#  ('krono', 2.189341142057872),
#  ('rezulto', 2.189341142057872),
#  ('bato', 2.192138346678933),
#  ('bonega', 2.192138346678933),
#  ('dometo', 2.192138346678933),
#  ('ligi', 2.192138346678933),
#  ('trakti', 2.192138346678933),
#  ('gardisto', 2.194943397606542),
#  ('malofte', 2.194943397606542),
#  ('senmova', 2.194943397606542),
#  ('kruela', 2.1977563389831563),
#  ('magia', 2.1977563389831563),
#  ('simile', 2.1977563389831563),
#  ('zorgo', 2.1977563389831563),
#  ('gazeto', 2.200577215324798),
#  ('imperiestro', 2.200577215324798),
#  ('konduti', 2.200577215324798),
#  ('konduto', 2.200577215324798),
#  ('rajdi', 2.200577215324798),
#  ('socio', 2.200577215324798),
#  ('dume', 2.2034060715252757),
#  ('facila', 2.206242952860475),
#  ('ondo', 2.206242952860475),
#  ('provo', 2.206242952860475),
#  ('verki', 2.206242952860475),
#  ('hela', 2.2090879049927064),
#  ('brilo', 2.214802206256145),
#  ('mantelo', 2.214802206256145),
#  ('sole', 2.214802206256145),
#  ('dependi', 2.2176716486840977),
#  ('enhavi', 2.2176716486840977),
#  ('laboristo', 2.2176716486840977),
#  ('partio', 2.2176716486840977),
#  ('puno', 2.2176716486840977),
#  ('trompi', 2.2176716486840977),
#  ('dekstra', 2.220549348511713),
#  ('ekde', 2.220549348511713),
#  ('ekstera', 2.220549348511713),
#  ('germana', 2.220549348511713),
#  ('sistemo', 2.220549348511713),
#  ('societo', 2.220549348511713),
#  ('perei', 2.223435353400848),
#  ('panjo', 2.2263297114272125),
#  ('antikva', 2.229232471085174),
#  ('lango', 2.229232471085174),
#  ('pozicio', 2.229232471085174),
#  ('penetri', 2.2321436812926323),
#  ('vigla', 2.2321436812926323),
#  ('avinjo', 2.235063391395967),
#  ('redoni', 2.235063391395967),
#  ('resi', 2.235063391395967),
#  ('tridek', 2.235063391395967),
#  ('ligita', 2.2379916511750553),
#  ('ok', 2.2379916511750553),
#  ('valori', 2.2379916511750553),
#  ('valoro', 2.2379916511750553),
#  ('informo', 2.2438740210781223),
#  ('monda', 2.2438740210781223),
#  ('motivo', 2.2438740210781223),
#  ('po', 2.2438740210781223),
#  ('profesoro', 2.2438740210781223),
#  ('sana', 2.2438740210781223),
#  ('fundo', 2.2468282329755533),
#  ('haltigi', 2.2468282329755533),
#  ('malsupre', 2.2468282329755533),
#  ('ekzemplo', 2.2497911981062106),
#  ('festo', 2.2497911981062106),
#  ('frukto', 2.2497911981062106),
#  ('botelo', 2.252762968495368),
#  ('kalkuli', 2.252762968495368),
#  ('milda', 2.252762968495368),
#  ('reciproke', 2.252762968495368),
#  ('ateni', 2.255743596633506),
#  ('kunulo', 2.255743596633506),
#  ('rigari', 2.255743596633506),
#  ('apogi', 2.258733135481872),
#  ('plendi', 2.258733135481872),
#  ('ekstari', 2.2617316384781283),
#  ('brilanta', 2.2647391595420836),
#  ('onklino', 2.2647391595420836),
#  ('timigi', 2.2647391595420836),
#  ('emi', 2.2677557530815093),
#  ('kapabla', 2.2677557530815093),
#  ('sukceso', 2.2677557530815093),
#  ('vesti', 2.2677557530815093),
#  ('ekparoli', 2.2707814739980465),
#  ('informi', 2.2707814739980465),
#  ('libereco', 2.2707814739980465),
#  ('sperto', 2.2707814739980465),
#  ('k', 2.2738163776932003),
#  ('kavaliro', 2.2738163776932003),
#  ('konsili', 2.2738163776932003),
#  ('trono', 2.2738163776932003),
#  ('vintro', 2.2738163776932003),
#  ('eksidi', 2.2768605200744285),
#  ('freneza', 2.2768605200744285),
#  ('kolera', 2.2768605200744285),
#  ('sci', 2.2768605200744285),
#  ('hai', 2.2799139575613188),
#  ('homaro', 2.2799139575613188),
#  ('kompati', 2.2799139575613188),
#  ('pinto', 2.2799139575613188),
#  ('rozo', 2.2799139575613188),
#  ('diferenco', 2.2829767470918645),
#  ('jarcento', 2.2829767470918645),
#  ('sako', 2.2829767470918645),
#  ('trairi', 2.2829767470918645),
#  ('gvidi', 2.286048946128835),
#  ('kadavro', 2.286048946128835),
#  ('klaso', 2.286048946128835),
#  ('najbaro', 2.286048946128835),
#  ('dubi', 2.289130612666243),
#  ('justeco', 2.289130612666243),
#  ('kesto', 2.289130612666243),
#  ('linio', 2.289130612666243),
#  ('trankvilo', 2.289130612666243),
#  ('bastono', 2.292221805235916),
#  ('deklivo', 2.292221805235916),
#  ('dubo', 2.292221805235916),
#  ('instigi', 2.2953225829141637),
#  ('kafo', 2.2953225829141637),
#  ('sciigo', 2.2953225829141637),
#  ('bruligi', 2.2984330053285564),
#  ('dezerto', 2.2984330053285564),
#  ('eligi', 2.2984330053285564),
#  ('povo', 2.2984330053285564),
#  ('reteni', 2.2984330053285564),
#  ('farti', 2.3015531326648),
#  ('humoro', 2.3015531326648),
#  ('kvara', 2.3015531326648),
#  ('radiko', 2.3015531326648),
#  ('tiamaniere', 2.3015531326648),
#  ('trafi', 2.3015531326648),
#  ('elpensi', 2.304683025673728),
#  ('peto', 2.304683025673728),
#  ('sopiri', 2.304683025673728),
#  ('boai', 2.3078227456783953),
#  ('malagrabla', 2.3078227456783953),
#  ('malami', 2.3078227456783953),
#  ('superi', 2.3078227456783953),
#  ('alvoki', 2.310972354581292),
#  ('maldekstra', 2.310972354581292),
#  ('nebulo', 2.310972354581292),
#  ('ordinare', 2.310972354581292),
#  ('prei', 2.310972354581292),
#  ('servo', 2.310972354581292),
#  ('stulta', 2.310972354581292),
#  ('surmeti', 2.310972354581292),
#  ('tendo', 2.310972354581292),
#  ('vetero', 2.310972354581292),
#  ('aventuro', 2.31413191487166),
#  ('plia', 2.31413191487166),
#  ('sonorilo', 2.31413191487166),
#  ('epoko', 2.317301489632939),
#  ('atako', 2.320481142550319),
#  ('detalo', 2.320481142550319),
#  ('distingi', 2.320481142550319),
#  ('sti', 2.320481142550319),
#  ...]

# %%
from scipy.sparse.linalg import svds
import numpy as np

# %%
def create_table(data_vectorized, k, name):
    u, sigma, vt = svds(data_vectorized, k)
    print(sigma)
    with open(name + str(k) + '.npy', 'wb') as f:
        np.save(f, np.dot(np.diag(sigma), vt).T)

# %%
create_table(esp_data_vectorized, 1024, "esp_sigma_v")
# Out:
# [ 0.14508604  0.14529951  0.14544627 ...  4.78065603  7.01406035
#  28.35116013]

# %%
# делаем векторы размера n * m : n = 5 (размер n - граммы), m = 1024 (размер вектора)

# %%
with open('result.txt', 'r') as file:
    f = open('texts_to_vectors.txt', 'w')
    for line in file.readlines():
        for word in line.split():
            try:
                pos =
# Out:
# 17864

# %%
from bisect import bisect_left 
import numpy as np
def binary_search(a, x): 
    i = bisect_left(a, x) 
    if i != len(a) and a[i] == x: 
        return i 
    else: 
        return -1

def texts_to_series(text_path = 'result.txt', dictionary_path = 'dictionary.txt', table_path = 'esp_sigma_v1024.npy'):
    with open(dictionary_path, 'r') as my_dict:
        dictionary = [word.strip() for word in my_dict.readlines()]
    table = np.load(table_path)
    with open(text_path, 'r') as texts:
        with open('vectorized_texts.txt', 'w') as file:
            for text in texts.readlines():
                for word in text.split():
                    word_index = binary_search(dictionary, word)
                    if word_index != -1:
                        word_vector = table[word_index]
                        for word in reversed(word_vector):
                            file.write(str(word))
                            file.write(' ')
                file.write('\n')

# %%
create_table(esp_data_vectorized, 8, "esp_sigma_v")
# Out:
# [ 2.91070343  3.38073138  3.51769953  3.92386255  4.29448547  4.78065603
#   7.01406035 28.35116013]

# %%
texts_to_series(table_path='esp_sigma_v8.npy')
